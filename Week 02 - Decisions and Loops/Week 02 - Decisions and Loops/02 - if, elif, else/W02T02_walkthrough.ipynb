# %% [markdown]
# # Week 2 · Topic 2 — if, elif, else
#
# **Box we are building: PROCESS, properly**
#
# Booleans decide something is true. This is where the program acts on it.
#
# > **Already know this?** Skip to the *Topic 2 Challenge*.

# %% [markdown]
# ---
# ## 1. `if`
#
# The indented block only runs when the condition is `True`. Nothing special happens
# when it is `False` — Python just moves on.

# %%
value = 23.7
limit = 20

if value > limit:
    print("OVER")

# %% [markdown]
# ### Your turn
# Write an `if` that prints `LOCKED` when `attempts >= 3`.

# %%
# your code here

# %% [markdown]
# ---
# ## 2. `else`
#
# Runs when the `if` condition was `False`. Exactly one of the two branches runs — never
# both, never neither.

# %%
if value > limit:
    print("OVER")
else:
    print("OK")

# %% [markdown]
# ```
# check: value > limit ?
#    │
#    ├── True  ──▶ print("OVER")
#    │
#    └── False ──▶ print("OK")
# ```

# %% [markdown]
# ### Your turn
# Add an `else` to your answer above that prints `OK`.

# %%
# your code here

# %% [markdown]
# ---
# ## 3. `elif`
#
# Checked top to bottom. The **first** `True` one runs, and the rest are skipped — even if
# they are also `True`. Put the most specific condition first.

# %%
percent = 105.0

if percent >= 100:
    status = "OVER LIMIT"
elif percent >= 90:
    status = "WARNING"
else:
    status = "OK"

print(status)

# %% [markdown]
# ```
# check: percent >= 100 ?
#    │
#    ├── True  ──▶ status = "OVER LIMIT"        (done - the rest is skipped)
#    │
#    └── False ──▶ check: percent >= 90 ?
#                     │
#                     ├── True  ──▶ status = "WARNING"   (done)
#                     │
#                     └── False ──▶ status = "OK"
# ```
# Each `elif` only runs if every check above it was False. The moment one branch
# fires, the rest are skipped — that is why order matters.

# %% [markdown]
# ### Your turn
# Write the 3-tier version for a `percent` of your choice: `OVER LIMIT` (100+), `WARNING` (90+), otherwise `OK`.

# %%
# your code here

# %% [markdown]
# ---
# ## 4. Indentation is syntax, not style
#
# Python has no `{ }`. The indented lines **are** the block. Miss it, and Python does not
# guess what you meant — it stops.

# %%
if value > limit:
    print("checking...")   # part of the if
    print("OVER")           # part of the if
print("done")                # NOT indented - runs either way

# %% [markdown]
# ### Your turn
# Write an `if` / `elif` / `else` where every keyword lines up in the same column, each with two indented lines inside it.

# %%
# your code here

# %% [markdown]
# ---
# ## Topic 2 Challenge
#
# A login has `failed_attempts` and a limit of 3. Print `LOCKED` if at or over the limit,
# `WARNING` if exactly one below it, otherwise `OK`. Test it with `failed_attempts` set to
# `1`, `2` and `3`.

# %%
# your code here

# %% [markdown]
# ---
# ## Same idea, three fields
#
# | Field | Looks like |
# |---|---|
# | **AI / Data Science** | `if missing_pct > 5: print("check pipeline")` |
# | **Cyber Security** | `if failed_logins >= 3: print("LOCKED")` |
# | **IT** | `if disk_used_pct >= 90: print("ALERT")` |

# %% [markdown]
# ---
# ## Common mistakes
#
# | Mistake | What you see | Fix |
# |---|---|---|
# | missing `:` | `SyntaxError` | every `if` / `elif` / `else` line ends with `:` |
# | next line not indented | `IndentationError` | indent consistently — 4 spaces |
# | `if x = 5:` | `SyntaxError` | you meant `==` |
# | broad condition checked before the specific one | wrong branch runs, no error | order `elif` chains most-specific first |
#
# ## Go deeper
#
# `examples/01_if_elif_else.py` — if / else / elif, and getting the order wrong
# `examples/02_indentation.py` — what breaks, and what the error actually says

# %% [markdown]
# ---
# ## Recap
#
# | You can now | Using |
# |---|---|
# | choose a path | `if` |
# | the alternative | `else` |
# | more than two paths | `elif` |
# | Python's blocks | indentation, not braces |
#
# **Next:** Topic 3 — repeating something until a condition changes.
