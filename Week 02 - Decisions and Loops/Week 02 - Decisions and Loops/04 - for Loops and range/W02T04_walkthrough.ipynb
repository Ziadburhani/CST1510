# %% [markdown]
# # Week 2 · Topic 4 — for Loops and range
#
# **Box we are building: PROCESS, the tidy way**
#
# When you already know how many times to repeat, `for` says so directly.
#
# > **Already know this?** Skip to the *Topic 4 Challenge*.

# %% [markdown]
# ---
# ## 1. `for i in range(n)`
#
# Repeats exactly `n` times. `i` takes `0, 1, 2, ...` up to but **not including** `n`.

# %%
for i in range(5):
    print(i)

# %% [markdown]
# ```
# for i in range(5):
#       i takes, in order:   0 ──▶ 1 ──▶ 2 ──▶ 3 ──▶ 4
#       the indented block runs once for each value, then the loop just ends
#       - no condition to check, no risk of it running forever
# ```

# %% [markdown]
# ### Your turn
# Print `Record 1` through `Record 5` — not `Record 0` through `Record 4`.

# %%
# your code here

# %% [markdown]
# ---
# ## 2. `range(start, stop)`
#
# `stop` is never included. This is where most `for` mistakes happen.

# %%
for i in range(1, 6):
    print(i)   # 1 2 3 4 5

for i in range(1, 5):
    print(i)   # 1 2 3 4 - not 5

# %% [markdown]
# ### Your turn
# Print the numbers 1 to 10, inclusive.

# %%
# your code here

# %% [markdown]
# ---
# ## 3. `range(start, stop, step)`
#
# Counting by more than one at a time — or counting down, with a negative step.

# %%
for i in range(10, 0, -1):
    print(i)   # 10 9 8 ... 1

# %% [markdown]
# ### Your turn
# Print every even number from 2 to 10.

# %%
# your code here

# %% [markdown]
# ---
# ## 4. `for` vs `while`
#
# Know the count in advance → `for`. Waiting on a condition or a signal → `while`
# (Topic 3). `for` can loop a fixed number of records even before you have a real list of
# them to loop over — Week 4 will replace `range(n)` with the real data.

# %%
for i in range(3):
    value = float(input("Value: "))
    print(value)

# %% [markdown]
# ### Your turn
# Use a `for` loop to ask for 3 values and print their total.

# %%
# your code here

# %% [markdown]
# ---
# ## 5. `enumerate()` — the index, for free
#
# Looping and needing to know *which one you are on* is common enough that Python
# has a shortcut — `enumerate()` hands you the position and the value together, so
# you never have to track a counter by hand.

# %%
for i, letter in enumerate("cat"):
    print(i, letter)

# %% [markdown]
# ```
# enumerate("cat")  ──▶  (0, 'c'), (1, 'a'), (2, 't')
#                            │         │
#                       position    value — both, at the same time
# ```
#
# `start=` shifts where the counting begins — useful for human-friendly numbering,
# since people count from 1, not 0.

# %%
for i, letter in enumerate("cat", start=1):
    print(f"letter {i}: {letter}")

# %% [markdown]
# ### Your turn
# Given `word = "python"`, use `enumerate(word, start=1)` to print `Character 1: p`
# through `Character 6: n`.

# %%
# your code here

# %% [markdown]
# ---
# ## Topic 4 Challenge
#
# Ask for and check exactly 5 records in one run, using a `for` loop. For each one, print
# whether it is `OVER LIMIT` or `OK` — reuse your `if` / `elif` / `else` from Topic 2.

# %%
# your code here

# %% [markdown]
# ---
# ## Same idea, three fields
#
# | Field | Looks like |
# |---|---|
# | **AI / Data Science** | process a fixed batch of `n` rows |
# | **Cyber Security** | check a fixed list of `n` known IPs |
# | **IT** | ping a fixed set of `n` servers |

# %% [markdown]
# ---
# ## Common mistakes
#
# | Mistake | What you see | Fix |
# |---|---|---|
# | `range(5)` expecting 1–5 | gives 0–4 | starts at 0 unless you say otherwise |
# | `range(1, 5)` expecting 1–5 | gives 1–4 | `stop` is never included — use `range(1, 6)` |
# | using `for` when you do not know the count in advance | only works if you guess right | that is what `while` is for |
# | changing `i` inside the loop, expecting it to affect the count | no effect | `range()` already decided every value in advance |
# | `for i in enumerate(x):` — forgetting to unpack | `i` is a whole `(0, 'c')` pair, not just the index | unpack both: `for i, value in enumerate(x):` |
#
# ## Go deeper
#
# `examples/01_for_and_range.py` — start, stop, step, what does not change `i`, and `enumerate()`
# `examples/02_for_vs_while.py` — the same job written both ways, and how to choose

# %% [markdown]
# ---
# ## Recap
#
# | You can now | Using |
# |---|---|
# | repeat n times | `for i in range(n):` |
# | choose the range | `range(start, stop)` — `stop` excluded |
# | count by steps | `range(start, stop, step)` |
# | get the index and the value together | `for i, value in enumerate(x):` |
# | pick the right tool | known count → `for`, unknown → `while` |
#
# **You now have both PROCESS tools for Week 2.** Go and build your own in the lab.
