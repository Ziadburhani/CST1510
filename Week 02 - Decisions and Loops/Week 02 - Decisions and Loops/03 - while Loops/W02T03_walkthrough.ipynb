# %% [markdown]
# # Week 2 · Topic 3 — while Loops
#
# **Box we are building: PROCESS, repeated**
#
# So far your program runs once, top to bottom. This is how it repeats.
#
# > **Already know this?** Skip to the *Topic 3 Challenge*.

# %% [markdown]
# ---
# ## 1. `while`
#
# Repeats the block while the condition is `True`. Same indentation rule as `if`.

# %%
count = 1

while count <= 3:
    print(count)
    count += 1

print("done")

# %% [markdown]
# ```
# check: count <= 3 ?
#    │
#    ├── True  ──▶ print(count)  ──▶  count += 1  ──▶  back to check
#    │
#    └── False ──▶ done
# ```
# Follow the arrows. The loop only ends when the path reaches **False** — which
# is exactly why `count += 1` has to be inside the loop. Leave it out and every
# lap takes the True branch, forever.

# %% [markdown]
# ### Your turn
# Print `hello` 5 times using a counter and `while`.

# %%
# your code here

# %% [markdown]
# ---
# ## 2. The condition must change, or it never stops
#
# Every error so far has printed a message and stopped. An infinite loop does neither —
# the program is just still running. If it happens to you: interrupt the kernel, do not
# wait it out.
#
# Read this — **do not run it**:
#
# ```python
# count = 1
# while count <= 3:
#     print(count)
# # count is never updated, so the condition is True forever
# ```

# %% [markdown]
# ### Your turn
# Without running anything, say out loud what line is missing from the code above, and what it should do.

# %% [markdown]
# ---
# ## 3. `while True:` + `break`
#
# Loop until something inside the loop decides to stop, instead of counting in advance.
# This is what you use when you do not know how many times you will repeat.

# %%
while True:
    answer = input("Another? (y/n): ")
    if answer == "n":
        break
    print("okay, again")

# %% [markdown]
# ### Your turn
# Write a loop that keeps asking `Password: ` and stops when it equals `python123`.

# %%
# your code here

# %% [markdown]
# ---
# ## 4. `break` and `continue`
#
# `break` exits the loop immediately. `continue` skips the rest of this pass and goes
# straight back to checking the condition.

# %%
n = 0
while n < 5:
    n += 1
    if n == 3:
        continue     # skip printing 3
    print(n)

# %% [markdown]
# ### Your turn
# Write a loop that asks for numbers until the user types `done`, but uses `continue` to skip adding anything when they enter a blank line.

# %%
# your code here

# %% [markdown]
# ---
# ## Topic 3 Challenge
#
# Keep a running total of numbers entered by the user. Stop when they type `done`. Print
# the total once the loop ends.

# %%
# your code here

# %% [markdown]
# ---
# ## Same idea, three fields
#
# | Field | Looks like |
# |---|---|
# | **AI / Data Science** | keep pulling batches while more data is available |
# | **Cyber Security** | keep checking log lines until a sentinel or end of file |
# | **IT** | keep checking a server's status until it responds healthy |

# %% [markdown]
# ---
# ## Common mistakes
#
# | Mistake | What happens | Fix |
# |---|---|---|
# | forgetting to update what the condition checks | runs forever | make sure something inside the loop changes it |
# | `while count = 5:` | `SyntaxError` | you meant `==`, or `while count < 5:` |
# | `while True:` with no `break` anywhere | runs forever | every `while True:` needs an exit |
# | condition checks the wrong variable | runs the wrong number of times, or never stops | trace it by hand with real numbers first |
#
# ## Go deeper
#
# `examples/01_while_basics.py` — the basic shape, and the infinite loop explained
# `examples/02_sentinel_and_running_total.py` — stopping on a signal, running totals, counting

# %% [markdown]
# ---
# ## Recap
#
# | You can now | Using |
# |---|---|
# | repeat while true | `while condition:` |
# | avoid running forever | update what the condition checks |
# | loop until a signal | `while True:` + `if ...: break` |
# | skip an iteration | `continue` |
# | stop immediately | `break` |
#
# **Next:** Topic 4 — repeating a fixed number of times, the tidy way.
