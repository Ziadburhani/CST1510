# %%
print("Record check starting")

print('single quotes')
print("double quotes")

print("Record", "R-004", "checked")

print("Value", 23.7)

print("=" * 34)
print("  RECORD CHECK")
print("=" * 34)

print("=" * 34)
print("  RECORD CHECK")
print("=" * 34)

print("line one\nline two")

print("ID\tVALUE")
print("R-004\t23.7")

# Show the report header
print("=" * 20)

record_id = "R-004"
value = 23.7
limit = 20

print(record_id)
print(value)
print(limit)
# Out:
# Record check starting
# single quotes
# double quotes
# Record R-004 checked
# Value 23.7
# ...
#   RECORD CHECK
# ...
#   RECORD CHECK
# ...
# line one
# line two
# ID	VALUE
# R-004	23.7
# ...
# R-004
# 23.7
# 20
